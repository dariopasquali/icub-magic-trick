# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None  # default='warn'

from time_series_extractor import *
from SubjectMagicFeatures import *
from featureExtractor import *
from plot_tools import *
from lie_plot_tools import *
#card_names = ['unicorn', 'minion', 'pig', 'aliens']

#%matplotlib notebook

# %%
mode = "none"
features, base_right, base_left = extractLieFeatures(mode=mode)
features
# Out:
# LOAD s3 from frontiers
# LOAD s4 from frontiers
# LOAD s5 from frontiers
# LOAD s8 from frontiers
# LOAD s10 from frontiers
# LOAD s13 from frontiers
# LOAD s16 from frontiers
# LOAD s18 from frontiers
# LOAD s20 from frontiers
# LOAD s25 from frontiers
#    subject     source card_class show_order duration react_dur  \
# 0        3  frontiers    unicorn          5     7055      1339
# 1        3  frontiers     pepper          2    13782      2290
# 2        3  frontiers     minion          1     8117      1307
# 3        3  frontiers        pig          0    24532      8827
# 4        3  frontiers      hedge          3    12106      2125
# 5        3  frontiers     aliens          4    10638      1817
# 6        4  frontiers    unicorn          1    18276      3579
# 7        4  frontiers     pepper          3    11185      1554
# 8        4  frontiers     minion          2     8293      1597
# 9        4  frontiers        pig          5    12413      2021
# ...

# %%
lie_plotBySubject(features, feat_cols=lie_feat_cols, mode=mode, save=False)
plt.show()
# Out:
# /home/dario/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# /home/dario/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
lie_plotComparBars(features, base_right, base_left, mode="none", save=False)
plt.show()
